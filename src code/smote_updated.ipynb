# %%
from google.colab import drive
drive.mount('/content/drive')
/content/drive/MyDrive/Colab Notebooks/Twitter Sentiment Analysis
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SVMSMOTE
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek
sm = SMOTE(random_state=42)
cou=0

for i in range(1,49):
    fname='dataset/'+str(i)+'n.csv'
    df=np.genfromtxt(fname,delimiter=',')
    datan=df[:,0:-1]
    out=df[:,-1]
    X_res, y_res = sm.fit_resample(datan,out)
    y=y_res.reshape(-1,1)
    d=np.concatenate((X_res,y),axis=1)
    fname='dataset/'+str(48+i)+'n.csv'
    np.savetxt(fname,d, delimiter=',', fmt='%f')

# %%
sm = BorderlineSMOTE(random_state=42)
cou=0

for i in range(1,49):
    fname='dataset/'+str(i)+'n.csv'
    df=np.genfromtxt(fname,delimiter=',')
    datan=df[:,0:-1]
    out=df[:,-1]
    X_res, y_res = sm.fit_resample(datan,out)
    y=y_res.reshape(-1,1)
    d=np.concatenate((X_res,y),axis=1)
    fname='dataset/'+str(48*2+i)+'n.csv'
    np.savetxt(fname,d, delimiter=',', fmt='%f')

# %%
sm = SVMSMOTE(random_state=42)
cou=0

for i in range(1,49):
    fname='dataset/'+str(i)+'n.csv'
    df=np.genfromtxt(fname,delimiter=',')
    datan=df[:,0:-1]
    out=df[:,-1]
    X_res, y_res = sm.fit_resample(datan,out)
    y=y_res.reshape(-1,1)
    d=np.concatenate((X_res,y),axis=1)
    fname='dataset/'+str(48*3+i)+'n.csv'
    np.savetxt(fname,d, delimiter=',', fmt='%f')

# %%
sm = SMOTEENN(random_state=42)
cou=0

for i in range(1,49):
    fname='dataset/'+str(i)+'n.csv'
    df=np.genfromtxt(fname,delimiter=',')
    datan=df[:,0:-1]
    out=df[:,-1]
    X_res, y_res = sm.fit_resample(datan,out)
    y=y_res.reshape(-1,1)
    d=np.concatenate((X_res,y),axis=1)
    fname='dataset/'+str(48*4+i)+'n.csv'
    np.savetxt(fname,d, delimiter=',', fmt='%f')

# %%
sm = SMOTETomek(random_state=42)
cou=0

for i in range(1,49):
    fname='dataset/'+str(i)+'n.csv'
    df=np.genfromtxt(fname,delimiter=',')
    datan=df[:,0:-1]
    out=df[:,-1]
    X_res, y_res = sm.fit_resample(datan,out)
    y=y_res.reshape(-1,1)
    d=np.concatenate((X_res,y),axis=1)
    fname='dataset/'+str(48*5+i)+'n.csv'
    np.savetxt(fname,d, delimiter=',', fmt='%f')
